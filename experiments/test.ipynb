# %%
from utils import read_files
df_final = read_files('/home/david/Documents/HAR/data/harth')
df_final
# Out:
#       label  back_x_mean  back_y_mean  back_z_mean  thigh_x_mean  \
# 0         6     0.411119     0.530922     0.654678      0.430068
# 1         6     0.058488     0.546527     0.648487      0.189075
# 2         6     0.058748     0.544272     0.650079      0.191715
# 3         6     0.059559     0.543623     0.652405      0.193063
# 4         6     0.061604     0.544082     0.658848      0.194262
# ...     ...          ...          ...          ...           ...
# 6747      7     0.107636     0.348245     0.350265      0.674581
# 6748      7     0.043507     0.453591     0.367682      0.677611
# 6749      1     0.063046     0.486917     0.324397      0.296648
# 6750      1     0.060559     0.469871     0.333471      0.244898
# 6751      6     0.072114     0.453704     0.327688      0.249381
#
#       thigh_y_mean  thigh_z_mean  vector_mag_back_mean  vector_mag_thigh_mean  \
# 0         0.464049      0.145233              0.000000               0.000000
# ...

# %%
from utils import make_dataframe

datares = make_dataframe('/home/david/Documents/HAR/data/harth/S012.csv')
datares
# Out:
#       label  back_x_mean  back_y_mean  back_z_mean  thigh_x_mean  \
# 0         3     0.427621     0.685902     0.515545      0.511289
# 1         3     0.080612     0.779344     0.474143      0.222620
# 2         3     0.065314     0.679353     0.528069      0.189233
# 3         7     0.011454     0.768660     0.547437      0.585457
# 4         7     0.106296     0.714180     0.621894      0.588994
# ...     ...          ...          ...          ...           ...
# 7643      7     0.083464     0.706629     0.653665      0.579720
# 7644      7     0.095942     0.725184     0.680112      0.576334
# 7645      7     0.096446     0.719533     0.680310      0.576627
# 7646      7     0.088854     0.709750     0.663881      0.575234
# 7647      7     0.086977     0.709702     0.659634      0.574926
#
#       thigh_y_mean  thigh_z_mean  vector_mag_back_mean  vector_mag_thigh_mean  \
# 0         0.381927      0.135544              0.000000               0.000000
# ...
